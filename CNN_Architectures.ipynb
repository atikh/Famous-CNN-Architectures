# %% [markdown]
# <a href="https://colab.research.google.com/github/atikh/Famous-CNN-Architectures/blob/main/CNN_Architectures.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 5 Most Well-Known CNN Architectures Visualized are as bellow:
#
#   ∘ LeNet-5
#
#   ∘ AlexNet
#
#   ∘ VGG-16
#
#   ∘ Inception-v1/GoogLeNet
#
#   ∘ ResNet-50

# %%
# ALL IMPORTS
import keras,os
from keras.models import Sequential, Model
from keras.layers import Dense, Conv2D, MaxPool2D , Flatten ,AveragePooling2D, BatchNormalization, Dropout, concatenate, GlobalAveragePooling2D, ZeroPadding2D, Input, ReLU ,Add
import numpy as np

# %% [markdown]
# # LeNet-5

# %% [markdown]
# Lenet-5 is one of the earliest pre-trained models proposed by Yann LeCun and others in the year 1998.
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# LeNet-5
model_LeNet5 = Sequential()
 #   ↓
#Conv  1-1 # Pooling
model_LeNet5.add(Conv2D(filters=6, kernel_size=(5,5), strides=(1,1),  activation='tanh', padding='same' , input_shape=(28, 28, 1)))
model_LeNet5.add(AveragePooling2D(pool_size=(2,2),strides=(2,2), padding='valid'))

#Conv  2-1 # Pooling
model_LeNet5.add(Conv2D(filters=16, kernel_size=(5,5), strides=(1,1), activation='tanh', padding='valid'))
model_LeNet5.add(AveragePooling2D(pool_size=(2,2),strides=(2,2), padding='valid'))

#Conv  3-1 # Pooling
model_LeNet5.add(Conv2D(filters=120, kernel_size=(5,5), strides=(1,1), activation='tanh', padding='valid'))

#Dense # Dense #Dense 
model_LeNet5.add(Flatten())
model_LeNet5.add(Dense(units=84, activation='tanh'))
model_LeNet5.add(Dense(units=10, activation = 'softmax'))
#    ↓
model_LeNet5.summary()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_34 (Conv2D)          (None, 28, 28, 6)         156
#
#  average_pooling2d_12 (Avera  (None, 14, 14, 6)        0
#  gePooling2D)
#
#  conv2d_35 (Conv2D)          (None, 10, 10, 16)        2416
#
#  average_pooling2d_13 (Avera  (None, 5, 5, 16)         0
#  gePooling2D)
#
#  conv2d_36 (Conv2D)          (None, 1, 1, 120)         48120
#
#  flatten_8 (Flatten)         (None, 120)               0
#
#  dense_18 (Dense)            (None, 84)                10164
#
#  dense_19 (Dense)            (None, 10)                850
#
# ...
# Total params: 61,706
# Trainable params: 61,706
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # AlexNet

# %% [markdown]
# AlexNet is a popular convolutional neural network. It is similar to the LeNet-5 architecture but larger and deeper.
# ![2.png](data:image/png;base64,...)

# %% [markdown]
# ![Untitled.png](data:image/png;base64,...)

# %%
# AlexNet

AlexNet_model = Sequential()
#   ↓
#Conv  1-1 # Pooling
AlexNet_model.add(Conv2D(filters=96, kernel_size=(11, 11), strides=(4, 4), activation="relu", input_shape=(224, 224, 3)))
AlexNet_model.add(MaxPool2D(pool_size=(3, 3), strides= (2, 2)))

#Conv  2-1 # Pooling
AlexNet_model.add(Conv2D(filters=256, kernel_size=(5, 5), strides=(1, 1), activation="relu",padding="same"))
AlexNet_model.add(MaxPool2D(pool_size=(3, 3), strides=(2, 2)))

#Conv  3-1 #Conv  3-2  #Conv  3-3  # Pooling
AlexNet_model.add(Conv2D(filters=384, kernel_size=(3, 3),  strides=(1, 1), activation="relu",   padding="same"))
AlexNet_model.add(Conv2D(filters=384, kernel_size=(3, 3), strides=(1, 1), activation="relu", padding="same"))
AlexNet_model.add(Conv2D(filters=256, kernel_size=(3, 3),   strides=(1, 1), activation="relu", padding="same"))
AlexNet_model.add(MaxPool2D(pool_size=(3, 3), strides=(2, 2)))

#Dense+dropout 0.5 #Dense+dropout 0.5  #Dense
AlexNet_model.add(Flatten())
AlexNet_model.add(Dense(4096, activation="relu"))
AlexNet_model.add(Dropout(0.5))
AlexNet_model.add(Dense(4096, activation="relu"))
AlexNet_model.add(Dropout(0.5))
AlexNet_model.add(Dense(1000, activation="softmax"))

AlexNet_model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_11 (Conv2D)          (None, 54, 54, 96)        34944
#
#  max_pooling2d_6 (MaxPooling  (None, 26, 26, 96)       0
#  2D)
#
#  conv2d_12 (Conv2D)          (None, 26, 26, 256)       614656
#
#  max_pooling2d_7 (MaxPooling  (None, 12, 12, 256)      0
#  2D)
#
#  conv2d_13 (Conv2D)          (None, 12, 12, 384)       885120
#
#  conv2d_14 (Conv2D)          (None, 12, 12, 384)       1327488
#
#  conv2d_15 (Conv2D)          (None, 12, 12, 256)       884992
#
#  max_pooling2d_8 (MaxPooling  (None, 5, 5, 256)        0
#  2D)
#
#  flatten_1 (Flatten)         (None, 6400)              0
#
#  dense_3 (Dense)             (None, 4096)              26218496
#
#  dropout_2 (Dropout)         (None, 4096)              0
#
#  dense_4 (Dense)             (None, 4096)              16781312
#
# ...

# %% [markdown]
# # VGG NET 16

# %% [markdown]
# Visual Geometry Group 16 ,belongs to the Department of Science and Engineering of Oxford University
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![Untitled.png](data:image/png;base64,...)

# %%
# VGG-16
model_VGG16 = Sequential()
 #   ↓
#Conv  1-1 #Conv  1-2 # Pooling
model_VGG16.add(Conv2D(input_shape=(224,224,3),filters=64,kernel_size=(3,3),padding="same", activation="relu"))
model_VGG16.add(Conv2D(filters=64,kernel_size=(3,3),padding="same", activation="relu"))
model_VGG16.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))

#Conv  2-1 #Conv  2-2 # Pooling
model_VGG16.add(Conv2D(filters=128, kernel_size=(3,3), padding="same", activation="relu"))
model_VGG16.add(Conv2D(filters=128, kernel_size=(3,3), padding="same", activation="relu"))
model_VGG16.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))

#Conv  3-1 #Conv  3-2 #Conv  3-3 # Pooling
model_VGG16.add(Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu"))
model_VGG16.add(Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu"))
model_VGG16.add(Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu"))
model_VGG16.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))

#Conv  4-1 #Conv  4-2 #Conv  4-3 # Pooling
model_VGG16.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
model_VGG16.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
model_VGG16.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
model_VGG16.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))

#Conv  5-1 #Conv  5-2 #Conv  5-3 # Pooling
model_VGG16.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
model_VGG16.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
model_VGG16.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
model_VGG16.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))

#  Dense #  Dense #  Dense
model_VGG16.add(Flatten())
model_VGG16.add(Dense(units=4096,activation="relu"))
model_VGG16.add(Dense(units=4096,activation="relu"))
model_VGG16.add(Dense(units=2, activation="softmax"))
#    ↓

model_VGG16.summary()
# Out:
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_37 (Conv2D)          (None, 224, 224, 64)      1792
#
#  conv2d_38 (Conv2D)          (None, 224, 224, 64)      36928
#
#  max_pooling2d_9 (MaxPooling  (None, 112, 112, 64)     0
#  2D)
#
#  conv2d_39 (Conv2D)          (None, 112, 112, 128)     73856
#
#  conv2d_40 (Conv2D)          (None, 112, 112, 128)     147584
#
#  max_pooling2d_10 (MaxPoolin  (None, 56, 56, 128)      0
#  g2D)
#
#  conv2d_41 (Conv2D)          (None, 56, 56, 256)       295168
#
#  conv2d_42 (Conv2D)          (None, 56, 56, 256)       590080
#
#  conv2d_43 (Conv2D)          (None, 56, 56, 256)       590080
#
#  max_pooling2d_11 (MaxPoolin  (None, 28, 28, 256)      0
#  g2D)
#
#  conv2d_44 (Conv2D)          (None, 28, 28, 512)       1180160
#
#  conv2d_45 (Conv2D)          (None, 28, 28, 512)       2359808
#
# ...

# %% [markdown]
# # Inception-v1 /GoogLeNet

# %% [markdown]
# sparsely connected network architectures which will replace fully connected network architectures, especially inside convolutional layers are used to 1.avoid overfitting in bigger datasets and reduce existing computational resources.An Inception Module is an image model block that aims to approximate an optimal local sparse structure in a CNN. Put simply, it allows for us to use multiple types of filter size, instead of being restricted to a single filter size, in a single image block, which we then concatenate and pass onto the next layer. The inception layer is the core concept of a sparsely connected architecture..

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# below is how the conceptualized idea of GoogLeNet looks:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# GoogLeNet (or Inception v1) has  27 layers deep and  made of 9 inception blocks

# %% [markdown]
# ![Screenshot-from-2018-10-16-11-24-42-109x440.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# From the above table, we can see that there are 9 inception blocks. We can see two columns named #3x3 reduce and #5x5 reduce, which means the number of 1x1 filters used before applying 3x3 and 5x5 filters on the input. If the value of #3x3 reduce is 64, it means that 64 filters of 1x1 are applied before applying a 3x3 filter on the input. If the value of #5x5 reduce is 16, it means that 16 filters of 1x1 are applied before applying a 5x5 filter on the input. Note that applying filter means doing convolution on the input using a filter.
#
# We apply a 1x1 filter to decrease the spectral dimension. Spectral dimension means band, for example, if an input size for an inception block is 28x28x192, then 192 is called a band or spectral dimension. If we reduce that spectral dimension using a 1x1 filter, we can save a lot of computational power. We also apply a 1x1 filter before applying 3x3 and 5x5 to save the computational resources.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Incpetion V1 /GoogLeNet
#Model Development
#f=filters
def inception(x,f_1x1,f_3x3_reduce,f_3x3, f_5x5_reduce,f_5x5,f_pool, name='None'):
    conv_1x1 = Conv2D(f_1x1, kernel_size=(1,1), strides=1, padding='same', activation='relu')(x)

    conv_3x3 = Conv2D(f_3x3_reduce,kernel_size=(1,1), strides=1, padding='same', activation='relu')(x)
    conv_3x3 = Conv2D(f_3x3, kernel_size=(3,3), strides=1, padding='same', activation='relu')(conv_3x3)

    conv_5x5 = Conv2D(f_5x5_reduce, kernel_size=(1,1), strides=1, padding='same', activation='relu')(x)
    conv_5x5 = Conv2D(f_5x5, kernel_size=(5,5), strides=1, padding='same', activation='relu')(conv_5x5)

    pool = MaxPool2D(pool_size=(3,3), strides=1, padding='same')(x)
    pool = Conv2D(f_pool, kernel_size=(1,1), strides=1, padding='same', activation='relu')(pool)

    output = concatenate([conv_1x1,conv_3x3,conv_5x5,pool], axis=-1, name=name)
    return output

kernel_init = keras.initializers.glorot_uniform()
bias_init = keras.initializers.Constant(value=0.2)

# %%
CLASS_NUM = 10  #depends on classes 
#to optimize coding we create a new module
def repetious(x, name=None):
    layer = AveragePooling2D(pool_size=(5,5), strides=3, padding='valid')(x)
    layer = Conv2D(filters=128, kernel_size=(1,1), strides=1, padding='same', activation='relu')(layer)
    layer = Flatten()(layer)
    layer = Dense(units=256, activation='relu')(layer)
    layer = Dropout(0.4)(layer)
    layer = Dense(units=CLASS_NUM, activation='softmax', name=name)(layer)
    return layer

# %%
# Building the Incpetion V1 Model Architecture
IMAGE_SHAPE=(224, 224, 3)
def googlenet():
    X_in = Input(shape=IMAGE_SHAPE)
    
    # stage-1
    layer = Conv2D(filters=64, kernel_size=(7,7), strides=2, padding='same', activation='relu')(X_in)
    layer = MaxPool2D(pool_size=(3,3), strides=2, padding='same')(layer)
    layer = BatchNormalization()(layer)

    # stage-2
    layer = Conv2D(filters=64, kernel_size=(1,1), strides=1, padding='same', activation='relu')(layer)
    layer = Conv2D(filters=192, kernel_size=(3,3), strides=1, padding='same', activation='relu')(layer)
    layer = BatchNormalization()(layer)
    layer = MaxPool2D(pool_size=(3,3), strides=2, padding='same')(layer)

    # stage-3
    layer = inception(layer, 64, 96, 128, 16, 32, 32, name='Inc-1-1') #3a
    layer = inception(layer, 128, 128, 192, 32, 96, 64, name='Inc-1-2') #3b
    layer = MaxPool2D(pool_size=(3,3), strides=2, padding='same')(layer)

    # stage-4
    layer = inception(layer, 192, 96, 208, 16, 48, 64, name='Inc-2-1') #4a
    aux1  = repetious(layer, name='aux1')
    layer = inception(layer, 160, 112, 224, 24, 64, 64, name='Inc-2-2') #4b
    layer = inception(layer, 128, 128, 256, 24, 64, 64, name='Inc-2-3') #4c
    layer = inception(layer, 112, 144, 288, 32, 64, 64, name='Inc-2-4') #4d
    aux2  = repetious(layer, name='aux2')
    layer = inception(layer, 256, 160, 320, 32, 128, 128, name='Inc-2-5') #4e
    layer = MaxPool2D(pool_size=(3,3), strides=2, padding='same')(layer)
    
    # stage-5
    layer = inception(layer, 256, 160, 320, 32, 128, 128, name='Inc-3-1') #5a
    layer = inception(layer, 384, 192, 384, 48, 128, 128, name='Inc-3-2') #5b
    layer = AveragePooling2D(pool_size=(7,7), strides=1, padding='valid')(layer)
    
    # stage-6
    layer = Flatten()(layer)
    layer = Dropout(0.4)(layer)
    layer = Dense(units=256, activation='linear')(layer)
    main = Dense(units=CLASS_NUM, activation='softmax', name='main')(layer)
    
    model = Model(inputs=X_in, outputs=[main, aux1, aux2], name='inception_v1')

    return model
# Checking Model Summary
googlenet = googlenet()
googlenet.summary()
# Out:
# Model: "inception_v1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_13 (InputLayer)          [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d_260 (Conv2D)            (None, 112, 112, 64  9472        ['input_13[0][0]']
#                                 )
#
#  max_pooling2d_47 (MaxPooling2D  (None, 56, 56, 64)  0           ['conv2d_260[0][0]']
#  )
#
#  batch_normalization_89 (BatchN  (None, 56, 56, 64)  256         ['max_pooling2d_47[0][0]']
#  ormalization)
#
#  conv2d_261 (Conv2D)            (None, 56, 56, 64)   4160        ['batch_normalization_89[0][0]']
#
#  conv2d_262 (Conv2D)            (None, 56, 56, 192)  110784      ['conv2d_261[0][0]']
#
#  batch_normalization_90 (BatchN  (None, 56, 56, 192)  768        ['conv2d_262[0][0]']
#  ormalization)
#
# ...

# %% [markdown]
# # ResNet-50

# %% [markdown]
# The network has been created and acquainted by Microsoft.It is well-known due to its depth (to 152 layers) and the introduction of residual blocks.
#
# The ResNet-50 model consists of 5 stages each with a convolution and Identity block. Each convolution block has 3 convolution layers and each identity block also has 3 convolution layers. The ResNet-50 has over 23 million trainable parameters.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Skip Connection
# In ResNet architecture, a “shortcut” or a “skip connection” allows the gradient to be directly backpropagated to earlier layers.
# There are two main types of blocks are used in a ResNet, depending mainly on whether the input/output dimensions are the same or different.
# 1. Identity Block : where the input activation has the same dimension as the output activation.
#
# 2. Convolutional Block: when the input and output dimensions don’t match up. The difference with the identity block is that there is a CONV2D layer in the shortcut path.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
 #Identity Block
 
def Identity_Block(X, f1, f2, f3):

  X_shortcut = X
   
  X = Conv2D(filters=f1, kernel_size=(1, 1), strides=(1, 1), padding='valid', activation='relu')(X)
  X = BatchNormalization(axis=3)(X)

  X = Conv2D(filters=f2, kernel_size=(3, 3), strides=(1, 1), padding='same', activation='relu')(X)
  X = BatchNormalization(axis=3)(X)

  X = Conv2D(filters=f3, kernel_size=(1, 1), strides=(1, 1), padding='valid', activation='relu')(X)
  X = BatchNormalization(axis=3)(X)

  X = Add()([X, X_shortcut])# SKIP Connection

  return X
    
kernel_init = keras.initializers.glorot_uniform(seed=0)
bias_init = keras.initializers.Constant(value=0.2)

# %%
#Convolutional Block
def Convolutional_Block(X, f1, f2, f3, s=2):
    X_shortcut = X

    X = Conv2D(filters=f1, kernel_size=(1, 1), strides=(s, s), padding='valid', activation='relu')(X)
    X = BatchNormalization(axis=3)(X)

    X = Conv2D(filters=f2, kernel_size=(3, 3), strides=(1, 1), padding='same', activation='relu')(X)
    X = BatchNormalization(axis=3)(X)

    X = Conv2D(filters=f3, kernel_size=(1, 1), strides=(1, 1), padding='valid', activation='relu')(X)
    X = BatchNormalization(axis=3)(X)

    X_shortcut = Conv2D(filters=f3, kernel_size=(1, 1), strides=(s, s), padding='valid', activation='relu')(X_shortcut)
    X_shortcut = BatchNormalization(axis=3)(X_shortcut)

    X = Add()([X, X_shortcut])

    return X

kernel_init = keras.initializers.glorot_uniform(seed=0)
bias_init = keras.initializers.Constant(value=0.2)

# %% [markdown]
# The ResNet-50 model consists of 5 stages each with a convolution and Identity block. Each convolution block has 3 convolution layers and each identity block also has 3 convolution layers. The ResNet-50 has over 23 million trainable parameters.

# %% [markdown]
# ![0_9LqUp7XyEx1QNc6A.webp](data:image/webp;base64,...)

# %%
#ResNet-50 
IMAGE_SHAPE=(224, 224, 3)

def ResNet50(input_shape=IMAGE_SHAPE):

    X_input = Input(input_shape)

    X = ZeroPadding2D((3, 3))(X_input)

    X = Conv2D(64, (7, 7), strides=(2, 2), activation='relu')(X)
    X = BatchNormalization(axis=3)(X)
    X = MaxPool2D((3, 3), strides=(2, 2))(X)

    X = Convolutional_Block(X, 64, 64, 256, s=1)
    X = Identity_Block(X, 64, 64, 256)
    X = Identity_Block(X, 64, 64, 256)


    X = Convolutional_Block(X, 128, 128, 512, s=2)
    X = Identity_Block(X, 128, 128, 512)
    X = Identity_Block(X, 128, 128, 512)
    X = Identity_Block(X, 128, 128, 512)

    X = Convolutional_Block(X, 256, 256, 1024, s=2)
    X = Identity_Block(X, 256, 256, 1024)
    X = Identity_Block(X, 256, 256, 1024)
    X = Identity_Block(X, 256, 256, 1024)
    X = Identity_Block(X, 256, 256, 1024)
    X = Identity_Block(X, 256, 256, 1024)

    X = Convolutional_Block(X, 512, 512, 2048, s=2)
    X = Identity_Block(X, 512, 512, 2048)
    X = Identity_Block(X, 512, 512, 2048)

    X = AveragePooling2D(pool_size=(2, 2), padding='same')(X)
    
    model = Model(inputs=X_input, outputs=X, name='ResNet50')

    return model
  
kernel_init = keras.initializers.glorot_uniform(seed=0)
bias_init = keras.initializers.Constant(value=0.2)


# Checking Model Summary
ResNet50 = ResNet50()
ResNet50.summary()
# Out:
# Model: "ResNet50"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_11 (InputLayer)          [(None, 224, 224, 3  0           []
#                                 )]
#
#  zero_padding2d_8 (ZeroPadding2  (None, 230, 230, 3)  0          ['input_11[0][0]']
#  D)
#
#  conv2d_148 (Conv2D)            (None, 112, 112, 64  9472        ['zero_padding2d_8[0][0]']
#                                 )
#
#  batch_normalization_34 (BatchN  (None, 112, 112, 64  256        ['conv2d_148[0][0]']
#  ormalization)                  )
#
#  max_pooling2d_33 (MaxPooling2D  (None, 55, 55, 64)  0           ['batch_normalization_34[0][0]']
#  )
#
#  conv2d_149 (Conv2D)            (None, 55, 55, 64)   4160        ['max_pooling2d_33[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 55, 55, 64)  256         ['conv2d_149[0][0]']
#  ormalization)
#
# ...
